# %% [markdown]
# <a href="https://colab.research.google.com/github/1021114Carlos/ocw_mit_courses/blob/manufacturing_shop/6.041SC%20Probabilistic%20Systems/recitations/6_042_recitation_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# _the axioms:_
#
# _nonnegativity:_ $P(A)$ $\ge$ 0
#
# _normalization:_ $P(Ω)$ = 1
#
# _additivity:_ if $P(A ∩ B)$ =  ∅  then, $P(A ∪ B) = P(A) + P(B)$

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn2, venn2_circles, venn3_circles
import numpy as np

# %% [markdown]
# 1. Give a mathematical derivation of the formula
#
# $P((A ∩ B^c) ∪ (A^c ∩ B)) = P(A) + P(B) − 2P(A ∩ B)$

# %%
venn2(subsets=(7, 5, 3), set_labels=("A", "B"))
plt.show()

# %% [markdown]
# 2.

# %%
# 70% Chocolate lovers
# 60% Geniouses
# 40% Both
# Determine the probability a random person is neither a chocolate lover or genious.

venn2(subsets=(7, 6, 4), set_labels= ("C", "G"))
plt.show();

# %% [markdown]
# 2.

# %%
# 60% are genious
# 70 love chocolate
# 40 are both
# Probability of choosing one that is neither.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ca2380f915ef> in <cell line: 7>()
#       5
#       6 # Create the Venn diagram
# ----> 7 venn3([set1, set2, set3], names=["Set 1", "Set 2", "Set 3"])
#       8
#       9 # Customize the plot (optional)
#
# TypeError: venn3() got an unexpected keyword argument 'names'

# %%
venn3([set(["60"]), set(["70"]), set(["40"])]);

# %%
venn3(subsets = (10, 7, 10, 6, 10, 4), set_labels = ("C", "G", "B"));
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-fdbcbdeb0d53> in <cell line: 1>()
# ----> 1 venn3(subsets = (10, 7, 10, 6, 10, 4), set_labels = ("C", "G", "B"));
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_venn/_venn3.py in venn3(subsets, set_labels, set_colors, alpha, normalize_to, ax, subset_label_formatter)
#     348         subset_label_formatter = str
#     349
# --> 350     areas = compute_venn3_areas(subsets, normalize_to)
#     351     centers, radii = solve_venn3_circles(areas)
#     352     regions = compute_venn3_regions(centers, radii)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_venn/_venn3.py in compute_venn3_areas(diagram_areas, normalize_to, _minimal_area)
#      49     else:
#      50         areas = areas / total_area * normalize_to
# ---> 51         A_a = areas[0] + areas[2] + areas[4] + areas[6]
# ...

# %%
venn3(subsets = (1, 1, 1, 2, 1, 2, 2), set_labels = ('Set1', 'Set2', 'Set3'));

# %%
plt.figure(figsize=(4,4))
v = venn3(subsets=(1, 1, 1, 1, 1, 1, 1), set_labels = ('A', 'B', 'C'))
v.get_patch_by_id('100').set_alpha(1.0)
v.get_patch_by_id('100').set_color('white')
v.get_label_by_id('100').set_text('Unknown')
v.get_label_by_id('A').set_text('Set "A"')
c = venn3_circles(subsets=(1, 1, 1, 1, 1, 1, 1), linestyle='dashed')
c[0].set_lw(1.0)
c[0].set_ls('dotted')
plt.title("Sample Venn diagram")
plt.annotate('Unknown set', xy=v.get_label_by_id('100').get_position() - np.array([0, 0.05]), xytext=(-70,-70),
             ha='center', textcoords='offset points', bbox=dict(boxstyle='round,pad=0.5', fc='gray', alpha=0.1),
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.5',color='gray'))
plt.show()

# %%
figure, axes = plt.subplots(2, 2)
venn2(subsets={'10': 1, '01': 1, '11': 1}, set_labels = ('A', 'B'), ax=axes[0][0])
venn2_circles((1, 2, 3), ax=axes[0][1])
venn3(subsets=(1, 1, 1, 1, 1, 1, 1), set_labels = ('A', 'B', 'C'), ax=axes[1][0])
venn3_circles({'001': 10, '100': 20, '010': 21, '110': 13, '011': 14}, ax=axes[1][1])
plt.show()

# %%
set1 = set(['A', 'B', 'C', 'D'])
set2 = set(['B', 'C', 'D', 'E'])
set3 = set(['C', 'D',' E', 'F', 'G'])

venn3([set1, set2, set3], ('Set1', 'Set2', 'Set3'))
plt.show()
